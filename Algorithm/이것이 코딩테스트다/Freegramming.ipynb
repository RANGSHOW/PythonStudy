# %%
import collections 
numList = [1, 2, 4, 3, 2, 1, 2, 3, 4, 5, 2, 3, 4, 2, 3, 4]

countDict = dict(collections.Counter(numList))
print(countDict)
# Out:
# {1: 2, 2: 5, 4: 4, 3: 4, 5: 1}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y = [1, 4, 5, 8, 9, 5, 3]

# 출력되는 그래프 크기 설정
plt.figure(figsize=(10,6))

plt.plot(x, y, color='pink')
plt.show()
